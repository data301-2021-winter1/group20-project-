# %% [markdown]
# # Ashika Das

# %% [markdown]
# ## Research question/interests
# In this project, we want to study how the #MeToo movement affected the US male identifying population towards woman and their behaviour in the work place.
#
# - Are men of higher education level able recognize and respond to sexual assault in their work enviroment in a greater propertion than men of lower education levels?
#
# - Does yearly income of a man influence if they reflected on their behaviour towards women after the #MeToo movie?
#
# - What portion of men believe they have a greater risk of being accussed of sexual harassment is a disadvantage of being a man based on demographics?

# %%
import pandas as pd

# %%
responses = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
responses
# Out:
#       Unnamed: 0     StartDate        EndDate               q0001  \
# 0              1  5/10/18 4:01   5/10/18 4:06  Somewhat masculine
# 1              2  5/10/18 6:30   5/10/18 6:53  Somewhat masculine
# 2              3  5/10/18 7:02   5/10/18 7:09      Very masculine
# 3              4  5/10/18 7:27   5/10/18 7:31      Very masculine
# 4              5  5/10/18 7:35   5/10/18 7:42      Very masculine
# ...          ...           ...            ...                 ...
# 1610        1611  5/22/18 8:48   5/22/18 8:52  Not very masculine
# 1611        1612  5/22/18 9:15   5/22/18 9:24      Very masculine
# 1612        1613  5/22/18 9:22   5/22/18 9:39  Somewhat masculine
# 1613        1614  5/22/18 9:44   5/22/18 9:50  Somewhat masculine
# 1614        1615  5/22/18 9:55  5/22/18 10:00      Very masculine
#
#                      q0002                  q0004_0001  \
# 0       Somewhat important                Not selected
# 1       Somewhat important  Father or father figure(s)
# ...

# %%
responses.head()
# Out:
#    Unnamed: 0     StartDate       EndDate               q0001  \
# 0           1  5/10/18 4:01  5/10/18 4:06  Somewhat masculine
# 1           2  5/10/18 6:30  5/10/18 6:53  Somewhat masculine
# 2           3  5/10/18 7:02  5/10/18 7:09      Very masculine
# 3           4  5/10/18 7:27  5/10/18 7:31      Very masculine
# 4           5  5/10/18 7:35  5/10/18 7:42      Very masculine
#
#                 q0002                  q0004_0001                  q0004_0002  \
# 0  Somewhat important                Not selected                Not selected
# 1  Somewhat important  Father or father figure(s)                Not selected
# 2   Not too important  Father or father figure(s)                Not selected
# 3   Not too important  Father or father figure(s)  Mother or mother figure(s)
# 4      Very important                Not selected                Not selected
#
#              q0004_0003    q0004_0004    q0004_0005  ...               q0035  \
# ...

# %% [markdown]
# ### Task 1
#
# ### Data Analysis:

# %%
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

print("Number of rows and columns respectively:", responses.shape)
print("Columns in the dataset:", responses.columns)
# Out:
# Number of rows and columns respectively: (1615, 98)
# Columns in the dataset: Index(['Unnamed: 0', 'StartDate', 'EndDate', 'q0001', 'q0002', 'q0004_0001',
#        'q0004_0002', 'q0004_0003', 'q0004_0004', 'q0004_0005', 'q0004_0006',
#        'q0005', 'q0007_0001', 'q0007_0002', 'q0007_0003', 'q0007_0004',
#        'q0007_0005', 'q0007_0006', 'q0007_0007', 'q0007_0008', 'q0007_0009',
#        'q0007_0010', 'q0007_0011', 'q0008_0001', 'q0008_0002', 'q0008_0003',
#        'q0008_0004', 'q0008_0005', 'q0008_0006', 'q0008_0007', 'q0008_0008',
#        'q0008_0009', 'q0008_0010', 'q0008_0011', 'q0008_0012', 'q0009',
#        'q0010_0001', 'q0010_0002', 'q0010_0003', 'q0010_0004', 'q0010_0005',
#        'q0010_0006', 'q0010_0007', 'q0010_0008', 'q0011_0001', 'q0011_0002',
#        'q0011_0003', 'q0011_0004', 'q0011_0005', 'q0012_0001', 'q0012_0002',
#        'q0012_0003', 'q0012_0004', 'q0012_0005', 'q0012_0006', 'q0012_0007',
# ...

# %%
responses.describe(include='float64').T
# Out:
#          count  mean       std       min      25%       50%       75%  \
# weight  1615.0   1.0  1.438996  0.019744  0.10258  0.596892  1.010046
#
#              max
# weight  8.676606

# %%
responses.describe(include='object').T
# Out:
#             count unique                         top  freq
# StartDate    1615   1378               5/21/18 12:36     4
# EndDate      1615   1377                5/17/18 4:41     4
# q0001        1615      5          Somewhat masculine   826
# q0002        1615      5          Somewhat important   628
# q0004_0001   1615      2  Father or father figure(s)  1109
# ...           ...    ...                         ...   ...
# educ3        1615      3             College or more   997
# educ4        1615      4             College or more   515
# age3         1615      3                     35 - 64   855
# kids         1606      2                Has children  1065
# orientation  1615      4                    Straight  1408
#
# [96 rows x 4 columns]

# %% [markdown]
# ### Task 2-3
# ##### Load Data
# Check file types and encodings.

# %%
df_responses = responses.select_dtypes(include=['object']).copy()

# %% [markdown]
# Check delimiters (space, comma, tab).
# Check columns of dataframe

# %%
list(df_responses.columns)
# Out:
# ['StartDate',
#  'EndDate',
#  'q0001',
#  'q0002',
#  'q0004_0001',
#  'q0004_0002',
#  'q0004_0003',
#  'q0004_0004',
#  'q0004_0005',
#  'q0004_0006',
#  'q0005',
#  'q0007_0001',
#  'q0007_0002',
#  'q0007_0003',
#  'q0007_0004',
#  'q0007_0005',
#  'q0007_0006',
#  'q0007_0007',
#  'q0007_0008',
#  'q0007_0009',
#  'q0007_0010',
#  'q0007_0011',
#  'q0008_0001',
#  'q0008_0002',
#  'q0008_0003',
#  'q0008_0004',
#  'q0008_0005',
#  'q0008_0006',
#  'q0008_0007',
#  'q0008_0008',
#  'q0008_0009',
#  'q0008_0010',
#  'q0008_0011',
#  'q0008_0012',
#  'q0009',
#  'q0010_0001',
#  'q0010_0002',
#  'q0010_0003',
#  'q0010_0004',
#  'q0010_0005',
#  'q0010_0006',
#  'q0010_0007',
#  'q0010_0008',
#  'q0011_0001',
#  'q0011_0002',
#  'q0011_0003',
#  'q0011_0004',
#  'q0011_0005',
#  'q0012_0001',
#  'q0012_0002',
#  'q0012_0003',
#  'q0012_0004',
#  'q0012_0005',
#  'q0012_0006',
#  'q0012_0007',
#  'q0013',
#  'q0014',
#  'q0015',
#  'q0017',
#  'q0018',
#  'q0019_0001',
# ...

# %% [markdown]
# ### Clean Data

# %%
#Remove columns not being used, selecting columns of specfifc questions to answer research question
data = df_responses[['q0011_0002','q0012_0001','q0012_0002','q0012_0003','q0012_0004','q0012_0005','q0012_0006','q0012_0007','q0015','q0029','q0034','age3']]

# %%
#Viewing missing data from men who did not complete the full survey
data.isnull().sum()
# Out:
# q0011_0002    735
# q0012_0001    735
# q0012_0002    735
# q0012_0003    735
# q0012_0004    735
# q0012_0005    735
# q0012_0006    735
# q0012_0007    735
# q0015         873
# q0029           0
# q0034           2
# age3            0
# dtype: int64

# %%
#Deal with missing data, dropping NaN values (All participants who did not complete the full survey.) and resetting indexing
data = data.dropna().reset_index()

# %%
#Deal with “incorrect” data, removing extra column of index and replace dataframe 
data.drop('index', axis=1, inplace=True)

# %%
#listing all columns of new dataframe
list(data.columns)
# Out:
# ['q0011_0002',
#  'q0012_0001',
#  'q0012_0002',
#  'q0012_0003',
#  'q0012_0004',
#  'q0012_0005',
#  'q0012_0006',
#  'q0012_0007',
#  'q0015',
#  'q0029',
#  'q0034',
#  'age3']

# %%
#replacing column names with the associated with the column
data = data.rename(columns = {'q0011_0002' :'It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment',
 'q0012_0001' :'Responded to a sexual harassment incident by: Confronted the accused person',
 'q0012_0002' : 'Responded to a sexual harassment incident by: :Contacted the HR department',
 'q0012_0003': 'Responded to a sexual harassment incident by: Contacted the manager of the accused person' ,
 'q0012_0004': 'Responded to a sexual harassment incident by: Reached out to the victim to offer support' ,
 'q0012_0005': 'Responded to a sexual harassment incident by: Did not respond at all',
 'q0012_0006': 'Responded to a sexual harassment incident by: Never witnessed sexual harassment' ,
 'q0012_0007': 'Responded to a sexual harassment incident by: Other',
 'q0015' : 'As a man, would you say you think about your behavior at work differently in the wake of #MeToo?',
 'q0029' : 'What was the last school you completed?',
 'q0034' : 'What is your yearly income?',
 'age3' : 'How old are you?'
})     
data.head()
# Out:
#   It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 0                                       Not selected
# 1  Greater risk of being accused of sexual harass...
# 2                                       Not selected
# 3                                       Not selected
# 4  Greater risk of being accused of sexual harass...
#
#   Responded to a sexual harassment incident by: Confronted the accused person  \
# 0                                       Not selected
# 1                                       Not selected
# 2                      Confronted the accused person
# 3                                       Not selected
# 4                                       Not selected
#
#   Responded to a sexual harassment incident by: :Contacted the HR department  \
# 0                                       Not selected
# 1                                       Not selected
# ...

# %%
#replacing terms into Yes and No, for easier analysis
data = data.replace('Other (please specify)','Yes').replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')

# %%
#sorting dataframe by age group
data = data.sort_values(by=['How old are you?'])

# %% [markdown]
# ## Task 3

# %% [markdown]
# #### Step 1

# %% [markdown]
# Method chaining

# %%
import pandas as pd
import numpy as np

# Method chaining begins

survey = (pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
.loc[:, ['q0011_0002',
 'q0012_0001',
 'q0012_0002',
 'q0012_0003',
 'q0012_0004',
 'q0012_0005',
 'q0012_0006',
 'q0012_0007',
 'q0015',
 'q0029',
 'q0034',
 'age3']]
.dropna().reset_index()
.drop('index', axis=1)
.rename(columns={"q0011_0002" :"It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment","q0012_0001" :"Responded to a sexual harassment incident by: Confronted the accused person","q0012_0002" : "Responded to a sexual harassment incident by: :Contacted the HR department","q0012_0003": "Responded to a sexual harassment incident by: Contacted the manager of the accused person", "q0012_0004": "Responded to a sexual harassment incident by: Reached out to the victim to offer support","q0012_0005": "Responded to a sexual harassment incident by: Did not respond at all","q0012_0006": "Responded to a sexual harassment incident by: Never witnessed sexual harassment","q0012_0007": "Responded to a sexual harassment incident by: Other","q0015" : "As a man, would you say you think about your behavior at work differently in the wake of #MeToo?","q0029" :"What was the last school you completed?","q0034" : "What is your yearly income?","age3" : "How old are you?"})
.replace('Other (please specify)','Yes')
.replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')
.sort_values(by=['How old are you?']))

# %% [markdown]
# #### Step 2

# %%
def load_and_process(pathname):

    # Method Chain 1 (Load data and deal with missing data)

    s1 = (
        pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
.loc[:, ['q0011_0002',
 'q0012_0001',
 'q0012_0002',
 'q0012_0003',
 'q0012_0004',
 'q0012_0005',
 'q0012_0006',
 'q0012_0007',
 'q0015',
 'q0029',
 'q0034',
 'age3']]
.dropna().reset_index()
.drop('index', axis=1)      
    )

    # Method Chain 2 (Create new columns, drop others, and do processing)

    s2 = (
          s1
        .rename(columns={"q0011_0002" :"It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment","q0012_0001" :"Responded to a sexual harassment incident by: Confronted the accused person","q0012_0002" : "Responded to a sexual harassment incident by: :Contacted the HR department","q0012_0003": "Responded to a sexual harassment incident by: Contacted the manager of the accused person", "q0012_0004": "Responded to a sexual harassment incident by: Reached out to the victim to offer support","q0012_0005": "Responded to a sexual harassment incident by: Did not respond at all","q0012_0006": "Responded to a sexual harassment incident by: Never witnessed sexual harassment","q0012_0007": "Responded to a sexual harassment incident by: Other","q0015" : "As a man, would you say you think about your behavior at work differently in the wake of #MeToo?","q0029" :"What was the last school you completed?","q0034" : "What is your yearly income?","age3" : "How old are you?"})
.replace('Other (please specify)','Yes')
.replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')
.sort_values(by=['How old are you?'])
      )
    # Make sure to return the latest dataframe

    return s2 

load_and_process("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
# Out:
#     It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 741                                                 No
# 665                                                 No
# 76                                                  No
# 75                                                  No
# 162                                                Yes
# ..                                                 ...
# 136                                                Yes
# 613                                                 No
# 289                                                Yes
# 604                                                 No
# 201                                                Yes
#
#     Responded to a sexual harassment incident by: Confronted the accused person  \
# 741                                                 No
# 665                                                 No
# ...

# %% [markdown]
# #### Load in File unprocessed file:
# Load in the file, an unprocessed version and a processed version

# %%
import project_functions2 as p2

# %%
data ='../data/raw/Data301rawresponses.csv'
x = p2.unprocessed(data)

# %% [markdown]
# ### Load in and process file

# %%
sur = p2.load_and_process(data)

# %% [markdown]
# ### Task 4

# %%
#Displaying columns and rows in dataset, with the type present
print("Number of rows and columns respectively:", sur.shape)
print("Columns in the dataset:", sur.columns)
# Out:
# Number of rows and columns respectively: (742, 12)
# Columns in the dataset: Index(['It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment',
#        'Responded to a sexual harassment incident by: Confronted the accused person',
#        'Responded to a sexual harassment incident by: :Contacted the HR department',
#        'Responded to a sexual harassment incident by: Contacted the manager of the accused person',
#        'Responded to a sexual harassment incident by: Reached out to the victim to offer support',
#        'Responded to a sexual harassment incident by: Did not respond at all',
#        'Responded to a sexual harassment incident by: Never witnessed sexual harassment',
#        'Responded to a sexual harassment incident by: Other',
#        'As a man, would you say you think about your behavior at work differently in the wake of #MeToo?',
#        'What was the last school you completed?',
# ...

# %%
#Describing dataset for a brief overview
sur.describe(include='object').T
# Out:
#                                                    count unique  \
# It’s a disadvantage to be a man at your work ri...   742      2
# Responded to a sexual harassment incident by: C...   742      2
# Responded to a sexual harassment incident by: :...   742      2
# Responded to a sexual harassment incident by: C...   742      2
# Responded to a sexual harassment incident by: R...   742      2
# Responded to a sexual harassment incident by: D...   742      2
# Responded to a sexual harassment incident by: N...   742      2
# Responded to a sexual harassment incident by: O...   742      2
# As a man, would you say you think about your be...   742      3
# What was the last school you completed?              742      6
# What is your yearly income?                          742     11
# How old are you?                                     742      3
#
#                                                                  top freq
# ...

# %% [markdown]
# ##### Analysis
# - A large majority of the men who completed the survey claim to never witnessed sexual harassment, when asked how they responded to a sexual harassment incident at work
# - The most common demographic of men who the survey were between the ages 35-64, yearly income between 50,000 and 74,999 USD and atleast had a college graduate degree
# - A large majority of the men who completed the survey did NOT think about their behavior at work differently in the wake of #MeToo

# %% [markdown]
# ##### Panda Analysis
# - Of the 742 who took the full survey, 50.7% believe that it’s a disadvantage to be a man at work right now due to a greater risk of being accused of sexual harassment
# - Of the 742 who took the survey the full survey, 65.9% believe they do not think about their behavior at work differently in the wake of #MeToo
# - Men who took the survey are generally between 35-64, with 37.9% of them being a college graduate and 17.7% of them making around 50,000-74,999 USD yearly (This is the highest frequnecy of the demographic of the men according to the survey)

# %%
#Graphing for income vs behaviour after MeToo with countplot
x= sns.countplot(y='What is your yearly income?', hue='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?'
, data=sur, palette="Blues_d")
plt.legend(title="",loc="upper right")
plt.title("The influence of yearly income on if men believe their behaviour at the work place changed after #MeToo movement")
plt.xlabel("The count of men who responded")
plt.ylabel('')
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The count plot shows us the relationship between the level of yearly income and the reflection of those men on if their behaviour is different with the social movemoment #MeToo. As we observe in every single range of yearly income, majority of the men said they do not think of their behaviour any different.

# %%
#Graphing for education vs behaviour after MeToo with countplot
sns.countplot(y='What was the last school you completed?', hue='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?', data=sur, palette="Reds")
plt.legend(title="")
plt.xlabel("The count of men who responded")
plt.ylabel('')
plt.title("The influence of education level on if men believe their behaviour at the work place changed after #MeToo movement")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The count plot shows us the relationship between the level of education and the reflection of those men on if their behaviour is different with the social movemoment #MeToo.We also observe in every single range of education, majority of the men said they do not think of their behaviour any different. The highest frequncy of men who did think of their behaviour differently were college graduates, which also has the highest frequnecy of those who did not. The number of men who said yes is nearly the same for post graduate degree and college graduate.

# %%
#Graphing for income vs disadvantage of being man (accused of sexual harassment) with countplot
sns.countplot(y='What is your yearly income?', hue='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, palette="Greens")
plt.legend(title="")
plt.xlabel("The count of men who responded")
plt.ylabel('')
plt.title("The influence of yearly income on if men believe they have a greater risk of being accused of sexual harassment in their work place")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The count plot shows us the relationship between the level of income and the frequency of men that consider the disadvantage of being a man at work right now is due to the greater risk of being accused for sexual harassment. We observed that with a larger yearly income (100,000 and above), there is an increasing number of men who believe that there is a greater risk of being accused of sexual harassment, relative to the total number of men in that pay range. Apart from the 0-9,999 pay range men earning between 10,000-99,999 USD yearly believe that it is not a disadvantage of being a man at their workpalce due to greater risk of being accussed of sexual harassment.

# %%
#Graphing for education vs disadvantage of being man (accused of sexual harassment) with countplot
sns.countplot(y='What was the last school you completed?', hue='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, palette="pastel")
plt.legend(title="")
plt.xlabel("The count of men who responded")
plt.ylabel('')
plt.title("The influence of education level on if men believe they have a greater risk of being accused of sexual harassment in their work place")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The count plot shows us the relationship between the level of education and the frequency of men that consider the disadvantage of being a man at work right now is due to the greater risk of being accused for sexual harassment.
# We observe post graduate degree holders do consider a greater risk, relative to the number of total post graduates who completed the survey. Those who had some college had the greatest relative frequncy that did not consider it a risk.

# %%
#Graphing for age vs disadvantage of being man (accused of sexual harassment) with countplot
sns.countplot(y='How old are you?', hue='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, palette="dark")
plt.legend(title="")
plt.xlabel("The count of men who responded")
plt.ylabel('')
plt.title("The influence of age on if men believe they have a greater risk of being accused of sexual harassment in their work place")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The count plot shows us the relationship between the age and the frequency of men that consider the disadvantage of being a man at work right now is due to the greater risk of being accused for sexual harassment.
# We observe that 35-64 is the large majority of the participants of the survey, however, relatively there is not a large observable difference in men who said yes/no.

# %%
#Graphing for education,age vs behaviour after MeToo with countplot
sns.catplot(x="As a man, would you say you think about your behavior at work differently in the wake of #MeToo?", y="What was the last school you completed?", hue="How old are you?",order=["No", "Yes"], data=sur)
plt.ylabel('')
plt.xlabel('')
plt.title("Relationship between level of education, age and if men believe their behaviour at the work place changed after #MeToo movement")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The graph looks at relationship between the level of education, the reflection of those men on if their behaviour is different with the social movemoment #MeToo and the age range of the men who completed the survey. There is a larger cluster of of 35-64 year old men who said with a High School or GED to if their behvaiour is different in the work place after #MeToo.

# %%
#Creating new dataframes of value count and joining through concat for new dataframe of combined answers and transposing, with horizontal bargraph
df = sur['Responded to a sexual harassment incident by: Confronted the accused person'].value_counts()
df1= sur['Responded to a sexual harassment incident by: :Contacted the HR department'].value_counts()
df2= sur['Responded to a sexual harassment incident by: Contacted the manager of the accused person'].value_counts()
df3=sur['Responded to a sexual harassment incident by: Did not respond at all'].value_counts()
df4=sur['Responded to a sexual harassment incident by: Never witnessed sexual harassment'].value_counts()
df5=sur['Responded to a sexual harassment incident by: Other'].value_counts()
result = pd.concat([df, df1, df2, df3, df4, df5], axis=1).T
ax = result.plot.barh(stacked=True, cmap='viridis', figsize=(10, 10))
plt.xlabel("The count of men who responded to the survey")
plt.title("Different ways of responding to sexual harassment in the workplace")
# Out:
# Text(0.5, 1.0, 'Different ways of responding to sexual harassment in the workplace')

# %% [markdown]
# ##### Graph Analysis
# The graph displays how those of who completed the survey responded to a case of sexual harrasment. Majority of the men who completed the survey claim to have never witnessed sexual harassment, with around 500 of the 742. All of the other methods of responding had under 100 responses, indicating that majority of participants did have never witnessed sexual harrasment.

# %%
#Graphing for education vs witnessing sexual harassment
sns.countplot(y='What was the last school you completed?', hue='Responded to a sexual harassment incident by: Never witnessed sexual harassment', data=sur, palette="Purples")
plt.legend(title="")
plt.xlabel("The count of men who responded")
plt.ylabel('')
plt.title("The influence of education level and never witnessing sexual harassment")
sns.despine()

# %% [markdown]
# ##### Graph Analysis
# The graph displays how those who responded to the survey and never have witnessed sexual harassment. Majority of the men who completed the survey claim to have never witnessed sexual harassment, with college graduates having the highest frequency saying they have never witnessed sexual harassment, relative to the total number of college graduates. This was followed by post-graduate degree holders.

# %% [markdown]
# #### Conclusion
#
#  Men's behavior in the workplace relatively remained unchanged regardless of the #MeToo social movement, regardless of higher education level, most men claim to never have witnessed sexual assault in their workplace. It was also interesting to see how based on demographics what portion of men considered being a man a disadvantage in the workplace.
#     Most men who completed the survey said to have never witnessed sexual harassment in their workplace, men with at least a college degree claimed to never have witnessed sexual harassment with the highest relative frequency of men saying yes, compared to men with different education levels. Post-graduates also had a high relative frequency of men who were said to have never witnessed sexual harassment. However, college graduates were the biggest demographic of the survey.
#     Regardless of income level, men in all income ranges did not think about their behavior in the workplace differently after the #MeToo movement. In all annual income ranges, men did say No to having thought about their behavior. In summary, income level does not influence their reflection on their behavior in the workplace as a man.
#     Based on demographics and visualization, an income level of 100,000 USD shows a greater number of men who believe that there is a greater risk of being accused of sexual harassment, relative to the total number of men in that pay range. Compared to men with lower income earning between men earning between 10,000-99,999 USD that is not a disadvantage. Based on education level post-graduate degree holders do consider a greater risk, relative to the number of total postgraduates who completed the survey, compared to men with some colleges did not consider it a risk. Indicating Postgraduate degree holders do consider a greater risk, relative to the number of total postgraduates who completed the survey. Those who had some college had the greatest relative to all those who had some college that did not consider it a risk. Based on age, relatively there is no influence on if they believe have a greater risk of being accused of sexual harassment is a disadvantage of being a man.
#     In summary, the MeToo movement did not have much of an impact on men's behavior, how and if they are able to identify and react to sexual assault in the workplace, and based on demographics education level, income does affect how men perceive the disadvantages of being a man in the workplace and most college-educated men claimed to have never have witnessed sexual assault in their workplace.
#     Further studies on how men view women in the workplace can better help understand how men view themselves and women in the workplace.

# %% [markdown]
# ### Milestone 4

# %% [markdown]
# ##### Converting dataframe with processed data into csv and exporting to processed data folder

# %%
sur.to_csv(r'../data/processed/processed_set2.csv')
