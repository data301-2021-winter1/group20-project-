# %% [markdown]
# # Ashika Das

# %% [markdown]
# ## Research question/interests
# How does the perspective of man on their role in society infleunce their behaviour towards women?

# %%
import pandas as pd

# %%
responses = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
responses
# Out:
#       Unnamed: 0     StartDate        EndDate               q0001  \
# 0              1  5/10/18 4:01   5/10/18 4:06  Somewhat masculine
# 1              2  5/10/18 6:30   5/10/18 6:53  Somewhat masculine
# 2              3  5/10/18 7:02   5/10/18 7:09      Very masculine
# 3              4  5/10/18 7:27   5/10/18 7:31      Very masculine
# 4              5  5/10/18 7:35   5/10/18 7:42      Very masculine
# ...          ...           ...            ...                 ...
# 1610        1611  5/22/18 8:48   5/22/18 8:52  Not very masculine
# 1611        1612  5/22/18 9:15   5/22/18 9:24      Very masculine
# 1612        1613  5/22/18 9:22   5/22/18 9:39  Somewhat masculine
# 1613        1614  5/22/18 9:44   5/22/18 9:50  Somewhat masculine
# 1614        1615  5/22/18 9:55  5/22/18 10:00      Very masculine
#
#                      q0002                  q0004_0001  \
# 0       Somewhat important                Not selected
# 1       Somewhat important  Father or father figure(s)
# ...

# %%
responses.head()
# Out:
#    Unnamed: 0     StartDate       EndDate               q0001  \
# 0           1  5/10/18 4:01  5/10/18 4:06  Somewhat masculine
# 1           2  5/10/18 6:30  5/10/18 6:53  Somewhat masculine
# 2           3  5/10/18 7:02  5/10/18 7:09      Very masculine
# 3           4  5/10/18 7:27  5/10/18 7:31      Very masculine
# 4           5  5/10/18 7:35  5/10/18 7:42      Very masculine
#
#                 q0002                  q0004_0001                  q0004_0002  \
# 0  Somewhat important                Not selected                Not selected
# 1  Somewhat important  Father or father figure(s)                Not selected
# 2   Not too important  Father or father figure(s)                Not selected
# 3   Not too important  Father or father figure(s)  Mother or mother figure(s)
# 4      Very important                Not selected                Not selected
#
#              q0004_0003    q0004_0004    q0004_0005  ...               q0035  \
# ...

# %% [markdown]
# ### Task 1
#
# ### Data Analysis:

# %%
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

print("Number of rows and columns respectively:", responses.shape)
print("Columns in the dataset:", responses.columns)
# Out:
# Number of rows and columns respectively: (1615, 98)
# Columns in the dataset: Index(['Unnamed: 0', 'StartDate', 'EndDate', 'q0001', 'q0002', 'q0004_0001',
#        'q0004_0002', 'q0004_0003', 'q0004_0004', 'q0004_0005', 'q0004_0006',
#        'q0005', 'q0007_0001', 'q0007_0002', 'q0007_0003', 'q0007_0004',
#        'q0007_0005', 'q0007_0006', 'q0007_0007', 'q0007_0008', 'q0007_0009',
#        'q0007_0010', 'q0007_0011', 'q0008_0001', 'q0008_0002', 'q0008_0003',
#        'q0008_0004', 'q0008_0005', 'q0008_0006', 'q0008_0007', 'q0008_0008',
#        'q0008_0009', 'q0008_0010', 'q0008_0011', 'q0008_0012', 'q0009',
#        'q0010_0001', 'q0010_0002', 'q0010_0003', 'q0010_0004', 'q0010_0005',
#        'q0010_0006', 'q0010_0007', 'q0010_0008', 'q0011_0001', 'q0011_0002',
#        'q0011_0003', 'q0011_0004', 'q0011_0005', 'q0012_0001', 'q0012_0002',
#        'q0012_0003', 'q0012_0004', 'q0012_0005', 'q0012_0006', 'q0012_0007',
# ...

# %%
responses.describe(include='float64').T
# Out:
#          count  mean       std       min      25%       50%       75%  \
# weight  1615.0   1.0  1.438996  0.019744  0.10258  0.596892  1.010046
#
#              max
# weight  8.676606

# %%
responses.describe(include='object').T
# Out:
#             count unique                         top  freq
# StartDate    1615   1378               5/21/18 12:36     4
# EndDate      1615   1377                5/17/18 4:41     4
# q0001        1615      5          Somewhat masculine   826
# q0002        1615      5          Somewhat important   628
# q0004_0001   1615      2  Father or father figure(s)  1109
# ...           ...    ...                         ...   ...
# educ3        1615      3             College or more   997
# educ4        1615      4             College or more   515
# age3         1615      3                     35 - 64   855
# kids         1606      2                Has children  1065
# orientation  1615      4                    Straight  1408
#
# [96 rows x 4 columns]

# %% [markdown]
# ### Task 2-3
# ##### Load in File unprocessed file:
#     Load in the file, an unprocessed version and a processed version

# %%
df_responses = responses.select_dtypes(include=['object']).copy()
df_responses
# Out:
#          StartDate        EndDate               q0001                 q0002  \
# 0     5/10/18 4:01   5/10/18 4:06  Somewhat masculine    Somewhat important
# 1     5/10/18 6:30   5/10/18 6:53  Somewhat masculine    Somewhat important
# 2     5/10/18 7:02   5/10/18 7:09      Very masculine     Not too important
# 3     5/10/18 7:27   5/10/18 7:31      Very masculine     Not too important
# 4     5/10/18 7:35   5/10/18 7:42      Very masculine        Very important
# ...            ...            ...                 ...                   ...
# 1610  5/22/18 8:48   5/22/18 8:52  Not very masculine  Not at all important
# 1611  5/22/18 9:15   5/22/18 9:24      Very masculine        Very important
# 1612  5/22/18 9:22   5/22/18 9:39  Somewhat masculine    Somewhat important
# 1613  5/22/18 9:44   5/22/18 9:50  Somewhat masculine    Somewhat important
# 1614  5/22/18 9:55  5/22/18 10:00      Very masculine  Not at all important
#
# ...

# %%
Check file types and encodings.
Check delimiters (space, comma, tab).
Skip rows and columns as needed.

# %%
print( df_responses.isnull().values.sum())
# Out:
# 20455

# %%
responses['q0001'].value_counts()
# Out:
# Somewhat masculine      826
# Very masculine          612
# Not very masculine      131
# Not at all masculine     32
# No answer                14
# Name: q0001, dtype: int64

# %% [raw]
# popcult = responses['q0004_0003'].value_counts()
# popcult

# %%
man = responses['q0015'].value_counts()
man
# Out:
# No           489
# Yes          247
# No answer      6
# Name: q0015, dtype: int64

# %% [markdown]
# Task 2

# %% [markdown]
# Load in File unprocessed file:
# Load in the file, an unprocessed version and a processed version

# %%
responses
# Out:
#       Unnamed: 0     StartDate        EndDate               q0001  \
# 0              1  5/10/18 4:01   5/10/18 4:06  Somewhat masculine
# 1              2  5/10/18 6:30   5/10/18 6:53  Somewhat masculine
# 2              3  5/10/18 7:02   5/10/18 7:09      Very masculine
# 3              4  5/10/18 7:27   5/10/18 7:31      Very masculine
# 4              5  5/10/18 7:35   5/10/18 7:42      Very masculine
# ...          ...           ...            ...                 ...
# 1610        1611  5/22/18 8:48   5/22/18 8:52  Not very masculine
# 1611        1612  5/22/18 9:15   5/22/18 9:24      Very masculine
# 1612        1613  5/22/18 9:22   5/22/18 9:39  Somewhat masculine
# 1613        1614  5/22/18 9:44   5/22/18 9:50  Somewhat masculine
# 1614        1615  5/22/18 9:55  5/22/18 10:00      Very masculine
#
#                      q0002                  q0004_0001  \
# 0       Somewhat important                Not selected
# 1       Somewhat important  Father or father figure(s)
# ...

# %%
list(responses.columns)
# Out:
# ['Unnamed: 0',
#  'StartDate',
#  'EndDate',
#  'q0001',
#  'q0002',
#  'q0004_0001',
#  'q0004_0002',
#  'q0004_0003',
#  'q0004_0004',
#  'q0004_0005',
#  'q0004_0006',
#  'q0005',
#  'q0007_0001',
#  'q0007_0002',
#  'q0007_0003',
#  'q0007_0004',
#  'q0007_0005',
#  'q0007_0006',
#  'q0007_0007',
#  'q0007_0008',
#  'q0007_0009',
#  'q0007_0010',
#  'q0007_0011',
#  'q0008_0001',
#  'q0008_0002',
#  'q0008_0003',
#  'q0008_0004',
#  'q0008_0005',
#  'q0008_0006',
#  'q0008_0007',
#  'q0008_0008',
#  'q0008_0009',
#  'q0008_0010',
#  'q0008_0011',
#  'q0008_0012',
#  'q0009',
#  'q0010_0001',
#  'q0010_0002',
#  'q0010_0003',
#  'q0010_0004',
#  'q0010_0005',
#  'q0010_0006',
#  'q0010_0007',
#  'q0010_0008',
#  'q0011_0001',
#  'q0011_0002',
#  'q0011_0003',
#  'q0011_0004',
#  'q0011_0005',
#  'q0012_0001',
#  'q0012_0002',
#  'q0012_0003',
#  'q0012_0004',
#  'q0012_0005',
#  'q0012_0006',
#  'q0012_0007',
#  'q0013',
#  'q0014',
#  'q0015',
#  'q0017',
#  'q0018',
# ...

# %%
responses = responses.rename(columns = {
 'q0001' :'In general, how masculine or “manly” do you feel?',
 'q0002' : 'How important is it to you that others see you as masculine?',
 'q0004_0001' : ,
 'q0004_0002',
 'q0004_0003',
 'q0004_0004',
 'q0004_0005',
 'q0004_0006',
 'q0005' : 'Do you think that society puts pressure on men in a way that is unhealthy or bad for them? ',
 'q0007_0001' : 'Ask a friend for professional advice',
 'q0007_0002' : 'Ask a friend for personal advice',
 'q0007_0003' : 'Express physical affection to male friends, like hugging, rubbing shoulders',
 'q0007_0004' : 'Cry',
 'q0007_0005' : 'Get in a physical fight with another person',
 'q0007_0006' : 'Have sexual relations with women, including anything from kissing to sex',
 'q0007_0007' : 'Have sexual relations with men, including anything from kissing to sex',
 'q0007_0008' : 'Watch sports of any kind' ,
 'q0007_0009' : 'Work out',
 'q0007_0010' : 'See a therapist',
 'q0007_0011' : 'Feel lonely or isolated',
 'q0008_0001' : 'I worry about my height, daily or nearly daily',
 'q0008_0002' : 'I worry about my weight, daily or nearly daily',
 'q0008_0003' : 'I worry about my hair/hairline, daily or nearly daily',
 'q0008_0004' : 'I worry about my physique, daily or nearly daily,
 'q0008_0005' : 'I worry about appearance of my genitalia, daily or nearly daily',
 'q0008_0006' : 'I worry about my clothing/style, daily or nearly daily',
 'q0008_0007' : 'I worry about my sexual performance/amount of sex, daily or nearly daily,
 'q0008_0008' : 'I worry about my mental health, daily or nearly daily',
 'q0008_0009' : 'I worry about my physical health, daily or nearly daily',
 'q0008_0010' : 'I worry about my finace, including currrent/future assest and debt, daily or nearly daily',
 'q0008_0011' : 'I worry about my ability to provide to family, current or future, daily or nearly daily',
 'q0008_0012' : 'None of the above',
 'q0009' : 'Which of the following categories best describes your employment status?',
 'q0010_0001' : 'At,
 'q0010_0002',
 'q0010_0003',
 'q0010_0004',
 'q0010_0005',
 'q0010_0006',
 'q0010_0007',
 'q0010_0008',
 'q0011_0001',
 'q0011_0002',
 'q0011_0003',
 'q0011_0004',
 'q0011_0005',
 'q0012_0001',
 'q0012_0002',
 'q0012_0003',
 'q0012_0004',
 'q0012_0005',
 'q0012_0006',
 'q0012_0007',
 'q0013',
 'q0014',
 'q0015',
 'q0017',
 'q0018',
 'q0019_0001',
 'q0019_0002',
 'q0019_0003',
 'q0019_0004',
 'q0019_0005',
 'q0019_0006',
 'q0019_0007',
 'q0020_0001',
 'q0020_0002',
 'q0020_0003',
 'q0020_0004',
 'q0020_0005',
 'q0020_0006',
 'q0021_0001',
 'q0021_0002',
 'q0021_0003',
 'q0021_0004',
 'q0022',
 'q0024',
 'q0025_0001',
 'q0025_0002',
 'q0025_0003',
 'q0026',
 'q0028',
 'q0029',
 'q0030',
 'q0034',
 'q0035',
 'q0036',
 'race2',
 'racethn4',
 'educ3',
 'educ4',
 'age3',
 'kids',
 'orientation',
 'weight'})
responses.head()
# Out:
#    Unnamed: 0     StartDate       EndDate  \
# 0           1  5/10/18 4:01  5/10/18 4:06
# 1           2  5/10/18 6:30  5/10/18 6:53
# 2           3  5/10/18 7:02  5/10/18 7:09
# 3           4  5/10/18 7:27  5/10/18 7:31
# 4           5  5/10/18 7:35  5/10/18 7:42
#
#   In general, how masculine or “manly” do you feel?  \
# 0                                Somewhat masculine
# 1                                Somewhat masculine
# 2                                    Very masculine
# 3                                    Very masculine
# 4                                    Very masculine
#
#   How important is it to you that others see you as masculine?  \
# 0                                 Somewhat important
# 1                                 Somewhat important
# 2                                  Not too important
# 3                                  Not too important
# 4                                     Very important
#
# ...
