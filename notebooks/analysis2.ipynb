# %% [markdown]
# # Ashika Das

# %% [markdown]
# ## Research question/interests
# -Are men of higher education level able recognize and respond to sexual assault in their work enviroment in a greater propertion than men of lower education levels?
#
# -Does yearly income of a man influence if they reflected on their behaviour towards women after the #MeToo movie?
#
# -What percentage of men believe they have a greater risk of being accussed of sexual harassment is a disadvantage of being a man based on demographics?

# %%
import pandas as pd

# %%
responses = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
responses
# Out:
#       Unnamed: 0     StartDate        EndDate               q0001  \
# 0              1  5/10/18 4:01   5/10/18 4:06  Somewhat masculine
# 1              2  5/10/18 6:30   5/10/18 6:53  Somewhat masculine
# 2              3  5/10/18 7:02   5/10/18 7:09      Very masculine
# 3              4  5/10/18 7:27   5/10/18 7:31      Very masculine
# 4              5  5/10/18 7:35   5/10/18 7:42      Very masculine
# ...          ...           ...            ...                 ...
# 1610        1611  5/22/18 8:48   5/22/18 8:52  Not very masculine
# 1611        1612  5/22/18 9:15   5/22/18 9:24      Very masculine
# 1612        1613  5/22/18 9:22   5/22/18 9:39  Somewhat masculine
# 1613        1614  5/22/18 9:44   5/22/18 9:50  Somewhat masculine
# 1614        1615  5/22/18 9:55  5/22/18 10:00      Very masculine
#
#                      q0002                  q0004_0001  \
# 0       Somewhat important                Not selected
# 1       Somewhat important  Father or father figure(s)
# ...

# %%
responses.head()
# Out:
#    Unnamed: 0     StartDate       EndDate               q0001  \
# 0           1  5/10/18 4:01  5/10/18 4:06  Somewhat masculine
# 1           2  5/10/18 6:30  5/10/18 6:53  Somewhat masculine
# 2           3  5/10/18 7:02  5/10/18 7:09      Very masculine
# 3           4  5/10/18 7:27  5/10/18 7:31      Very masculine
# 4           5  5/10/18 7:35  5/10/18 7:42      Very masculine
#
#                 q0002                  q0004_0001                  q0004_0002  \
# 0  Somewhat important                Not selected                Not selected
# 1  Somewhat important  Father or father figure(s)                Not selected
# 2   Not too important  Father or father figure(s)                Not selected
# 3   Not too important  Father or father figure(s)  Mother or mother figure(s)
# 4      Very important                Not selected                Not selected
#
#              q0004_0003    q0004_0004    q0004_0005  ...               q0035  \
# ...

# %% [markdown]
# ### Task 1
#
# ### Data Analysis:

# %%
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

print("Number of rows and columns respectively:", responses.shape)
print("Columns in the dataset:", responses.columns)
# Out:
# Number of rows and columns respectively: (1615, 98)
# Columns in the dataset: Index(['Unnamed: 0', 'StartDate', 'EndDate', 'q0001', 'q0002', 'q0004_0001',
#        'q0004_0002', 'q0004_0003', 'q0004_0004', 'q0004_0005', 'q0004_0006',
#        'q0005', 'q0007_0001', 'q0007_0002', 'q0007_0003', 'q0007_0004',
#        'q0007_0005', 'q0007_0006', 'q0007_0007', 'q0007_0008', 'q0007_0009',
#        'q0007_0010', 'q0007_0011', 'q0008_0001', 'q0008_0002', 'q0008_0003',
#        'q0008_0004', 'q0008_0005', 'q0008_0006', 'q0008_0007', 'q0008_0008',
#        'q0008_0009', 'q0008_0010', 'q0008_0011', 'q0008_0012', 'q0009',
#        'q0010_0001', 'q0010_0002', 'q0010_0003', 'q0010_0004', 'q0010_0005',
#        'q0010_0006', 'q0010_0007', 'q0010_0008', 'q0011_0001', 'q0011_0002',
#        'q0011_0003', 'q0011_0004', 'q0011_0005', 'q0012_0001', 'q0012_0002',
#        'q0012_0003', 'q0012_0004', 'q0012_0005', 'q0012_0006', 'q0012_0007',
# ...

# %%
responses.describe(include='float64').T
# Out:
#          count  mean       std       min      25%       50%       75%  \
# weight  1615.0   1.0  1.438996  0.019744  0.10258  0.596892  1.010046
#
#              max
# weight  8.676606

# %%
responses.describe(include='object').T
# Out:
#             count unique                         top  freq
# StartDate    1615   1378               5/21/18 12:36     4
# EndDate      1615   1377                5/17/18 4:41     4
# q0001        1615      5          Somewhat masculine   826
# q0002        1615      5          Somewhat important   628
# q0004_0001   1615      2  Father or father figure(s)  1109
# ...           ...    ...                         ...   ...
# educ3        1615      3             College or more   997
# educ4        1615      4             College or more   515
# age3         1615      3                     35 - 64   855
# kids         1606      2                Has children  1065
# orientation  1615      4                    Straight  1408
#
# [96 rows x 4 columns]

# %% [markdown]
# ### Task 2-3
# ##### Load in File unprocessed file:
#     Load in the file, an unprocessed version and a processed version

# %%
df_responses = responses.select_dtypes(include=['object']).copy()
df_responses
# Out:
#          StartDate        EndDate               q0001                 q0002  \
# 0     5/10/18 4:01   5/10/18 4:06  Somewhat masculine    Somewhat important
# 1     5/10/18 6:30   5/10/18 6:53  Somewhat masculine    Somewhat important
# 2     5/10/18 7:02   5/10/18 7:09      Very masculine     Not too important
# 3     5/10/18 7:27   5/10/18 7:31      Very masculine     Not too important
# 4     5/10/18 7:35   5/10/18 7:42      Very masculine        Very important
# ...            ...            ...                 ...                   ...
# 1610  5/22/18 8:48   5/22/18 8:52  Not very masculine  Not at all important
# 1611  5/22/18 9:15   5/22/18 9:24      Very masculine        Very important
# 1612  5/22/18 9:22   5/22/18 9:39  Somewhat masculine    Somewhat important
# 1613  5/22/18 9:44   5/22/18 9:50  Somewhat masculine    Somewhat important
# 1614  5/22/18 9:55  5/22/18 10:00      Very masculine  Not at all important
#
# ...

# %%
list(data.columns)
# Out:
# ['As a man, would you say you think about your behavior at work differently in the wake of #MeToo?',
#  'How old are you?',
#  'It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment',
#  'Responded to a sexual harassment incident by: :Contacted the HR department',
#  'Responded to a sexual harassment incident by: Confronted the accused person',
#  'Responded to a sexual harassment incident by: Contacted the manager of the accused person',
#  'Responded to a sexual harassment incident by: Did not respond at all',
#  'Responded to a sexual harassment incident by: Never witnessed sexual harassment',
#  'Responded to a sexual harassment incident by: Other',
#  'Responded to a sexual harassment incident by: Reached out to the victim to offer support',
#  'What is your yearly income?',
#  'What was the last school you completed?']

# %% [markdown]
# Check file types and encodings.
# Check delimiters (space, comma, tab).
# Skip rows and columns as needed.

# %%
#Remove columns not being used.
data = df_responses[['q0011_0002','q0012_0001','q0012_0002','q0012_0003','q0012_0004','q0012_0005','q0012_0006','q0012_0007','q0015','q0029','q0034','age3']]
data
# Out:
#                                              q0011_0002    q0012_0001  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                          Not selected  Not selected
# 3                                                   NaN           NaN
# 4     Greater risk of being accused of sexual harass...  Not selected
# ...                                                 ...           ...
# 1610                                       Not selected  Not selected
# 1611  Greater risk of being accused of sexual harass...  Not selected
# 1612  Greater risk of being accused of sexual harass...  Not selected
# 1613                                       Not selected  Not selected
# 1614                                                NaN           NaN
#
#         q0012_0002    q0012_0003    q0012_0004    q0012_0005  \
# 0              NaN           NaN           NaN           NaN
# ...

# %%
#Viewing missing data from men who did not complete the full survey
data.isnull().sum()
# Out:
# q0011_0002    735
# q0012_0001    735
# q0012_0002    735
# q0012_0003    735
# q0012_0004    735
# q0012_0005    735
# q0012_0006    735
# q0012_0007    735
# q0015         873
# q0029           0
# q0034           2
# age3            0
# dtype: int64

# %%
#Deal with missing data.
data = data.dropna().reset_index()
data
# Out:
#      index                                         q0011_0002  \
# 0        2                                       Not selected
# 1        4  Greater risk of being accused of sexual harass...
# 2        5                                       Not selected
# 3        8                                       Not selected
# 4        9  Greater risk of being accused of sexual harass...
# ..     ...                                                ...
# 737   1609  Greater risk of being accused of sexual harass...
# 738   1610                                       Not selected
# 739   1611  Greater risk of being accused of sexual harass...
# 740   1612  Greater risk of being accused of sexual harass...
# 741   1613                                       Not selected
#
#                         q0012_0001    q0012_0002    q0012_0003    q0012_0004  \
# 0                     Not selected  Not selected  Not selected  Not selected
# ...

# %%
#Deal with “incorrect” data.
data.drop('index', axis=1, inplace=True)
data
# Out:
#                                             q0011_0002  \
# 0                                         Not selected
# 1    Greater risk of being accused of sexual harass...
# 2                                         Not selected
# 3                                         Not selected
# 4    Greater risk of being accused of sexual harass...
# ..                                                 ...
# 737  Greater risk of being accused of sexual harass...
# 738                                       Not selected
# 739  Greater risk of being accused of sexual harass...
# 740  Greater risk of being accused of sexual harass...
# 741                                       Not selected
#
#                         q0012_0001    q0012_0002    q0012_0003    q0012_0004  \
# 0                     Not selected  Not selected  Not selected  Not selected
# 1                     Not selected  Not selected  Not selected  Not selected
# ...

# %%
list(data.columns)
# Out:
# ['q0011_0002',
#  'q0012_0001',
#  'q0012_0002',
#  'q0012_0003',
#  'q0012_0004',
#  'q0012_0005',
#  'q0012_0006',
#  'q0012_0007',
#  'q0015',
#  'q0029',
#  'q0034',
#  'age3']

# %%
data = data.rename(columns = {'q0011_0002' :'It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment',
 'q0012_0001' :'Responded to a sexual harassment incident by: Confronted the accused person',
 'q0012_0002' : 'Responded to a sexual harassment incident by: :Contacted the HR department',
 'q0012_0003': 'Responded to a sexual harassment incident by: Contacted the manager of the accused person' ,
 'q0012_0004': 'Responded to a sexual harassment incident by: Reached out to the victim to offer support' ,
 'q0012_0005': 'Responded to a sexual harassment incident by: Did not respond at all',
 'q0012_0006': 'Responded to a sexual harassment incident by: Never witnessed sexual harassment' ,
 'q0012_0007': 'Responded to a sexual harassment incident by: Other',
 'q0015' : 'As a man, would you say you think about your behavior at work differently in the wake of #MeToo?',
 'q0029' : 'What was the last school you completed?',
 'q0034' : 'What is your yearly income?',
 'age3' : 'How old are you?'
})     
data.head()
# Out:
#   It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 0                                       Not selected
# 1  Greater risk of being accused of sexual harass...
# 2                                       Not selected
# 3                                       Not selected
# 4  Greater risk of being accused of sexual harass...
#
#   Responded to a sexual harassment incident by: Confronted the accused person  \
# 0                                       Not selected
# 1                                       Not selected
# 2                      Confronted the accused person
# 3                                       Not selected
# 4                                       Not selected
#
#   Responded to a sexual harassment incident by: :Contacted the HR department  \
# 0                                       Not selected
# 1                                       Not selected
# ...

# %%
data = data.replace('Other (please specify)','Yes').replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')
data
# Out:
#     It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 0                                                   No
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 737                                                Yes
# 738                                                 No
# 739                                                Yes
# 740                                                Yes
# 741                                                 No
#
#     Responded to a sexual harassment incident by: Confronted the accused person  \
# 0                                                   No
# 1                                                   No
# ...

# %%
data = data.sort_values(by=['How old are you?'])

# %% [markdown]
# ## Task 3

# %% [markdown]
# #### Step 1

# %%
import pandas as pd
import numpy as np

survey = (pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
.loc[:, ['q0011_0002',
 'q0012_0001',
 'q0012_0002',
 'q0012_0003',
 'q0012_0004',
 'q0012_0005',
 'q0012_0006',
 'q0012_0007',
 'q0015',
 'q0029',
 'q0034',
 'age3']]
.dropna().reset_index()
.drop('index', axis=1)
.rename(columns={"q0011_0002" :"It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment","q0012_0001" :"Responded to a sexual harassment incident by: Confronted the accused person","q0012_0002" : "Responded to a sexual harassment incident by: :Contacted the HR department","q0012_0003": "Responded to a sexual harassment incident by: Contacted the manager of the accused person", "q0012_0004": "Responded to a sexual harassment incident by: Reached out to the victim to offer support","q0012_0005": "Responded to a sexual harassment incident by: Did not respond at all","q0012_0006": "Responded to a sexual harassment incident by: Never witnessed sexual harassment","q0012_0007": "Responded to a sexual harassment incident by: Other","q0015" : "As a man, would you say you think about your behavior at work differently in the wake of #MeToo?","q0029" :"What was the last school you completed?","q0034" : "What is your yearly income?","age3" : "How old are you?"})
.replace('Other (please specify)','Yes')
.replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')
.sort_values(by=['How old are you?']))
survey
# Out:
#     It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 741                                                 No
# 665                                                 No
# 76                                                  No
# 75                                                  No
# 162                                                Yes
# ..                                                 ...
# 136                                                Yes
# 613                                                 No
# 289                                                Yes
# 604                                                 No
# 201                                                Yes
#
#     Responded to a sexual harassment incident by: Confronted the accused person  \
# 741                                                 No
# 665                                                 No
# ...

# %% [markdown]
# #### Step 2

# %%
def load_and_process(pathname):

    # Method Chain 1 (Load data and deal with missing data)

     s1 = (pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
.loc[:, ['q0011_0002',
 'q0012_0001',
 'q0012_0002',
 'q0012_0003',
 'q0012_0004',
 'q0012_0005',
 'q0012_0006',
 'q0012_0007',
 'q0015',
 'q0029',
 'q0034',
 'age3']]
.dropna().reset_index()
.drop('index', axis=1)
         )

    # Method Chain 2 (Create new columns, drop others, and do processing)

    s2 = (
          s1
.rename(columns={"q0011_0002" :"It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment","q0012_0001" :"Responded to a sexual harassment incident by: Confronted the accused person","q0012_0002" : "Responded to a sexual harassment incident by: :Contacted the HR department","q0012_0003": "Responded to a sexual harassment incident by: Contacted the manager of the accused person", "q0012_0004": "Responded to a sexual harassment incident by: Reached out to the victim to offer support","q0012_0005": "Responded to a sexual harassment incident by: Did not respond at all","q0012_0006": "Responded to a sexual harassment incident by: Never witnessed sexual harassment","q0012_0007": "Responded to a sexual harassment incident by: Other","q0015" : "As a man, would you say you think about your behavior at work differently in the wake of #MeToo?","q0029" :"What was the last school you completed?","q0034" : "What is your yearly income?","age3" : "How old are you?"})
.replace('Other (please specify)','Yes')
.replace('Confronted the accused person','Yes').replace('Contacted the HR department','Yes').replace('Contacted the manager of the accused person','Yes').replace('Reached out to the victim to offer support','Yes').replace('Did not respond at all','Yes').replace('Never witnessed sexual harassment','Yes').replace('Greater risk of being accused of sexual harassment','Yes').replace('Not selected','No')
.sort_values(by=['How old are you?'])
      )
    # Make sure to return the latest dataframe

    return s2 

load_and_process("https://raw.githubusercontent.com/fivethirtyeight/data/master/masculinity-survey/raw-responses.csv")
# Out:
#     It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 741                                                 No
# 665                                                 No
# 76                                                  No
# 75                                                  No
# 162                                                Yes
# ..                                                 ...
# 136                                                Yes
# 613                                                 No
# 289                                                Yes
# 604                                                 No
# 201                                                Yes
#
#     Responded to a sexual harassment incident by: Confronted the accused person  \
# 741                                                 No
# 665                                                 No
# ...

# %% [markdown]
# Load in File unprocessed file:
# Load in the file, an unprocessed version and a processed version

# %%
import project_functions2 as p2

# %%
data ='../data/raw/Data301rawresponses.csv'
sur = p2.unprocessed(data)
sur
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26552/3272894436.py in <module>
#       1 data ='../data/raw/Data301rawresponses.csv'
# ----> 2 sur = p2.unprocessed(data)
#       3 sur
#
# AttributeError: module 'project_functions2' has no attribute 'unprocessed'

# %% [markdown]
# ### Load in and process file

# %%
sur = p2.load_and_process(data)
sur
# Out:
#     It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment  \
# 741                                                 No
# 665                                                 No
# 76                                                  No
# 75                                                  No
# 162                                                Yes
# ..                                                 ...
# 136                                                Yes
# 613                                                 No
# 289                                                Yes
# 604                                                 No
# 201                                                Yes
#
#     Responded to a sexual harassment incident by: Confronted the accused person  \
# 741                                                 No
# 665                                                 No
# ...

# %% [markdown]
# ### Task 4

# %%
print("Number of rows and columns respectively:", sur.shape)
print("Columns in the dataset:", sur.columns)
# Out:
# Number of rows and columns respectively: (742, 12)
# Columns in the dataset: Index(['It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment',
#        'Responded to a sexual harassment incident by: Confronted the accused person',
#        'Responded to a sexual harassment incident by: :Contacted the HR department',
#        'Responded to a sexual harassment incident by: Contacted the manager of the accused person',
#        'Responded to a sexual harassment incident by: Reached out to the victim to offer support',
#        'Responded to a sexual harassment incident by: Did not respond at all',
#        'Responded to a sexual harassment incident by: Never witnessed sexual harassment',
#        'Responded to a sexual harassment incident by: Other',
#        'As a man, would you say you think about your behavior at work differently in the wake of #MeToo?',
#        'What was the last school you completed?',
# ...

# %%
sur.describe(include='object').T
# Out:
#                                                    count unique  \
# It’s a disadvantage to be a man at your work ri...   742      2
# Responded to a sexual harassment incident by: C...   742      2
# Responded to a sexual harassment incident by: :...   742      2
# Responded to a sexual harassment incident by: C...   742      2
# Responded to a sexual harassment incident by: R...   742      2
# Responded to a sexual harassment incident by: D...   742      2
# Responded to a sexual harassment incident by: N...   742      2
# Responded to a sexual harassment incident by: O...   742      2
# As a man, would you say you think about your be...   742      3
# What was the last school you completed?              742      6
# What is your yearly income?                          742     11
# How old are you?                                     742      3
#
#                                                                  top freq
# ...

# %%
sns.countplot(y='What is your yearly income?', hue='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?', data=sur, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='count', ylabel='What is your yearly income?'>

# %%
sns.countplot(y='What was the last school you completed?', hue='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?', data=sur, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='count', ylabel='What was the last school you completed?'>

# %%
sns.countplot(y='What is your yearly income?', hue='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='count', ylabel='What is your yearly income?'>

# %%
sns.countplot(y='What was the last school you completed?', hue='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, palette="Blues_d")
# Out:
# <AxesSubplot:xlabel='count', ylabel='What was the last school you completed?'>

# %%
sns.catplot(x="As a man, would you say you think about your behavior at work differently in the wake of #MeToo?", y="What was the last school you completed?", hue="How old are you?",order=["No", "Yes"], data=sur)

# %%
sns.barplot(x='What is your yearly income?', y='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, estimator=lambda x: sum(x==0)*100.0/len(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26552/3223678153.py in <module>
# ----> 1 sns.barplot(x='What is your yearly income?', y='It’s a disadvantage to be a man at your work right now due to: Greater risk of being accused of sexual harassment', data=sur, estimator=lambda x: sum(x==0)*100.0/len(x))
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\miniconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# ...

# %%
df1 = sur.groupby(["What is your yearly income?"])

# %%
df2 = sur.sort_values('What was the last school you completed?')
df3 = pd.melt(df2, id_vars="What was the last school you completed?", value_vars=['Responded to a sexual harassment incident by: Confronted the accused person',
       'Responded to a sexual harassment incident by: :Contacted the HR department',
       'Responded to a sexual harassment incident by: Contacted the manager of the accused person',
       'Responded to a sexual harassment incident by: Reached out to the victim to offer support',
       'Responded to a sexual harassment incident by: Did not respond at all',
       'Responded to a sexual harassment incident by: Never witnessed sexual harassment',
       'Responded to a sexual harassment incident by: Other'],var_name ='What was the last school you completed?', value_name ='Recognization')
ax = sns.catplot(x="What was the last school you completed?",y="",hue="Region",data = sur,kind ="bar")
ax.fig.suptitle("Relationship between Game Sales and Genre")
ax.fig.set_size_inches(20,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26552/2247046309.py in <module>
#       7        'Responded to a sexual harassment incident by: Never witnessed sexual harassment',
#       8        'Responded to a sexual harassment incident by: Other'],var_name ='What was the last school you completed?', value_name ='Recognization')
# ----> 9 ax = sns.catplot(x="What was the last school you completed?",y="",hue="Region",data = sur,kind ="bar")
#      10 ax.fig.suptitle("Relationship between Game Sales and Genre")
#      11 ax.fig.set_size_inches(20,5)
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.jointplot(y='What is your yearly income?', x='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?', data=sur, kind='reg')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26552/2405884098.py in <module>
# ----> 1 sns.jointplot(y='What is your yearly income?', x='As a man, would you say you think about your behavior at work differently in the wake of #MeToo?', data=sur, kind='reg')
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\miniconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2311
#    2312         joint_kws.setdefault("color", color)
# ...

# %%
ax = sns.lmplot(data=sur, x="What is your yearly income?",y="As a man, would you say you think about your behavior at work differently in the wake of #MeToo?",hue="What is your yearly income?")
ax.fig.set_size_inches(15,10)
ax.fig.suptitle("Behaviour vs Income")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26552/2095188252.py in <module>
# ----> 1 ax = sns.lmplot(data=sur, x="What is your yearly income?",y="As a man, would you say you think about your behavior at work differently in the wake of #MeToo?",hue="What is your yearly income?")
#       2 ax.fig.set_size_inches(15,10)
#       3 ax.fig.suptitle("Behaviour vs Income")
#       4 plt.show()
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
